# %%
import os
from PIL import Image

fake_path = '/home/lebaozki/code/RayVinc/DeepFakeDetection/raw_data/training_fake'
real_path = '/home/lebaozki/code/RayVinc/DeepFakeDetection/raw_data/training_real'
fake = {}
real = {}

fake_list = os.listdir(fake_path)
real_list = os.listdir(real_path)

for filename in fake_list:
    if filename.lower().endswith(('.jpg', '.jpeg')):
        with Image.open(os.path.join(fake_path, filename)):
            fake[filename.trip()] = image

for filename in real_list:
    if filename.lower().endswith(('.jpg', '.jpeg')):
        with Image.open(os.path.join(real_path, filename)):
            fake[filename] = image

# %%
len(fake)
# Out:
# 2041

# %%
import matplotlib.pyplot as plt
plt.imshow(fake['hard_188_0100.jpg']);

# %%
print('no')
# Out:
# no
